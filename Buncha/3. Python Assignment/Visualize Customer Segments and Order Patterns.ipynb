# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('kmeans_data.csv')

# %%
df
# Out:
#      Unnamed: 0  total_spend  num_orders  cluster
# 0             0     1.051607   -0.852616        2
# 1             1    -0.290342    0.947823        0
# 2             2     1.568577   -1.140686        2
# 3             3    -0.124993    1.451946        0
# 4             4     0.340295    1.379929        4
# ..          ...          ...         ...      ...
# 995         995     0.033951   -1.572792        0
# 996         996     1.705198    0.299665        2
# 997         997     0.706507   -1.284722        4
# 998         998     0.985362    1.451946        4
# 999         999     1.287323   -0.924634        2
#
# [1000 rows x 4 columns]

# %%
# Visualize customer segments
plt.figure(figsize=(10, 6))
plt.scatter(df['total_spend'], df['num_orders'], c=df['cluster'], cmap='viridis')
plt.title('Customer Segmentation')
plt.xlabel('Total Spent')
plt.ylabel('Number of Orders')
plt.colorbar(label='Cluster')
plt.show()

# %%
# Visualize order patterns by segment
for segment in customer_data['segment'].unique():
    segment_data = customer_data[customer_data['segment'] == segment]
    plt.figure(figsize=(10, 6))
    plt.scatter(segment_data['total_spen'], segment_data['num_orders'], label=segment)
    plt.title(f'Order Patterns - {segment}')
    plt.xlabel('Total Spent')
    plt.ylabel('Number of Orders')
    plt.legend()
    plt.show()
